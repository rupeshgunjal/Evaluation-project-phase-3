# %%
import pandas as pd
import numpy as np

# %%
zomato= pd.read_csv(r'C:\Users\Dell\Downloads\zomato.csv' ,encoding='ISO-8859-1')

# %%
country_code_data=pd.read_csv(r"C:\Users\Dell\Downloads\\Country-Code.xlsx",encoding='ISO-8859-1', delimiter=';')

# %%
zomato
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
zomato.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
zomato = zomato.dropna()

# %%
zomato.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
columns_to_drop = ['Cuisines']
zomato = zomato.drop(columns=columns_to_drop)

# %%
zomato
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
columns_to_encode = ['Rating text','Rating color','City', 'Has Table booking', 'Currency','Restaurant Name','Has Online delivery','Is delivering now','Switch to order menu']

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to each column
for column in columns_to_encode:
    zomato[column + '_encoded'] = label_encoder.fit_transform(zomato[column])

# %%
from sklearn.preprocessing import *
le=LabelEncoder()

zomato['Restaurant Name']=le.fit_transform(zomato['Restaurant Name'])
zomato['Currency']=le.fit_transform(zomato['Currency'])
zomato['Has Table booking']=le.fit_transform(zomato['Has Table booking'])

zomato['Has Online delivery']=le.fit_transform(zomato['Has Online delivery'])

zomato['Is delivering now']=le.fit_transform(zomato['Is delivering now'])
zomato['City']=le.fit_transform(zomato['City'])
zomato['Rating text_encoded']=le.fit_transform(zomato['Rating text_encoded'])
zomato['Rating color_encoded']=le.fit_transform(zomato['Rating color_encoded'])


zomato
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  \
# 0           6317637             3743           162    73
# 1           6304287             3168           162    73
# 2           6300002             2893           162    75
# 3           6318506             4700           162    75
# 4           6314302             5515           162    75
# ...             ...              ...           ...   ...
# 9546        5915730             4436           208   139
# 9547        5908749             1311           208   139
# 9548        5915807             3064           208   139
# 9549        5916112              513           208   139
# 9550        5927402             7231           208   139
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# ...

# %%
zomato.drop(['Average Cost for two', 'Price range','Address','Locality','Locality Verbose'], axis=1)
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City   Longitude  \
# 0           6317637             3743           162    73  121.027535
# 1           6304287             3168           162    73  121.014101
# 2           6300002             2893           162    75  121.056831
# 3           6318506             4700           162    75  121.056475
# 4           6314302             5515           162    75  121.057508
# ...             ...              ...           ...   ...         ...
# 9546        5915730             4436           208   139   28.977392
# 9547        5908749             1311           208   139   29.041297
# 9548        5915807             3064           208   139   29.034640
# 9549        5916112              513           208   139   29.036019
# 9550        5927402             7231           208   139   29.026016
#
#        Latitude  Currency  Has Table booking  Has Online delivery  \
# 0     14.565443         0                  1                    0
# ...

# %%
X = zomato.drop(['Average Cost for two', 'Price range','Address','Locality','Locality Verbose','Rating color','Rating text'], axis=1)
y_cost = zomato['Average Cost for two']
y_price_range = zomato['Price range']

# %%
X
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City   Longitude  \
# 0           6317637             3743           162    73  121.027535
# 1           6304287             3168           162    73  121.014101
# 2           6300002             2893           162    75  121.056831
# 3           6318506             4700           162    75  121.056475
# 4           6314302             5515           162    75  121.057508
# ...             ...              ...           ...   ...         ...
# 9546        5915730             4436           208   139   28.977392
# 9547        5908749             1311           208   139   29.041297
# 9548        5915807             3064           208   139   29.034640
# 9549        5916112              513           208   139   29.036019
# 9550        5927402             7231           208   139   29.026016
#
#        Latitude  Currency  Has Table booking  Has Online delivery  \
# 0     14.565443         0                  1                    0
# ...

# %%
from sklearn.preprocessing import *
le=LabelEncoder()

X['Switch to order menu']=le.fit_transform(X['Switch to order menu'])

# %%
X.dtypes
# Out:
# Restaurant ID                     int64
# Restaurant Name                   int64
# Country Code                      int64
# City                              int64
# Longitude                       float64
# Latitude                        float64
# Currency                          int64
# Has Table booking                 int64
# Has Online delivery               int64
# Is delivering now                 int64
# Switch to order menu              int32
# Aggregate rating                float64
# Votes                             int64
# Rating text_encoded               int64
# Rating color_encoded              int64
# City_encoded                      int32
# Has Table booking_encoded         int32
# Currency_encoded                  int32
# Restaurant Name_encoded           int32
# Has Online delivery_encoded       int32
# Is delivering now_encoded         int32
# Switch to order menu_encoded      int32
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_cost_train, y_cost_test = train_test_split(X, y_cost, test_size=0.2, random_state=42)

# %%
y_cost_train
# Out:
# 8177    450
# 6401    700
# 81      120
# 1332    300
# 9041    500
#        ...
# 5743    250
# 5200    300
# 5399    500
# 869     100
# 7279    300
# Name: Average Cost for two, Length: 7633, dtype: int64

# %%
X_train.dtypes
# Out:
# Restaurant ID                     int64
# Restaurant Name                   int64
# Country Code                      int64
# City                              int64
# Longitude                       float64
# Latitude                        float64
# Currency                          int64
# Has Table booking                 int64
# Has Online delivery               int64
# Is delivering now                 int64
# Switch to order menu              int32
# Aggregate rating                float64
# Votes                             int64
# Rating text_encoded               int64
# Rating color_encoded              int64
# City_encoded                      int32
# Has Table booking_encoded         int32
# Currency_encoded                  int32
# Restaurant Name_encoded           int32
# Has Online delivery_encoded       int32
# Is delivering now_encoded         int32
# Switch to order menu_encoded      int32
# dtype: object

# %%
model_cost = LinearRegression()
model_cost.fit(X_train, y_cost_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
predictions_average_cost = model_cost.predict(X_test)
